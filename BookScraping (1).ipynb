# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://books.toscrape.com/'
response = requests.get(url)
response.encoding = 'utf-8'  #fix encoding

soup = BeautifulSoup(response.text, 'html.parser')
books = soup.find_all('article', class_ = 'product_pod')

data =[]
for book in books:
    title = book.h3.a['title']
    price_raw = book.find('p',class_='price_color').text.strip()
    price = price_raw.replace('£','').replace('A—','')
    availability = book.find('p',class_ = 'instock availability').text.strip()
    rating = book.find('p',class_ = 'star-rating')['class'][1]
    data.append({
        'Title': title,
        'Price (GBP)' : float(price),
        'Availability' : availability,
        'Rating' : rating
    })

df = pd.DataFrame(data)

df.to_csv('books_data.csv', index=False)

df.style.set_properties(**{
    'background-color' : '#f0f8ff',
    'color' : '#000',
    'border-color' : 'gray',
    'border-style' :'solid',
    'border-width' : '1px' ,
    'text-align' : 'left',
    'padding' : '5px'
}).highlight_max(subset=['Price (GBP)'], color='lightgreen') \
  .highlight_min(subset=['Price (GBP)'], color='lightcoral') \
  .set_caption("Book Data from books.toscrape.com")
# Out:
# <style type="text/css">
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd  # ✅ Corrected this line

url = 'https://books.toscrape.com/'
response = requests.get(url)
response.encoding = 'utf-8'  # Fix encoding

soup = BeautifulSoup(response.text, 'html.parser')
books = soup.find_all('article', class_='product_pod')

data = []
for book in books:
    title = book.h3.a['title']
    price_raw = book.find('p', class_='price_color').text.strip()
    price = price_raw.replace('£', '').replace('A—', '')  # You might not need 'A—'
    availability = book.find('p', class_='instock availability').text.strip()
    rating = book.find('p', class_='star-rating')['class'][1]

    data.append({
        'Title': title,
        'Price (GBP)': float(price),
        'Availability': availability,
        'Rating': rating
    })

df = pd.DataFrame(data)

df.to_csv('books_data.csv', index=False)

# Display in Jupyter Notebook (optional)
df.style.set_properties(**{
    'background-color': '#f0f8ff',
    'color': '#000',
    'border-color': 'gray',
    'border-style': 'solid',
    'border-width': '1px',
    'text-align': 'left',
    'padding': '5px'
}).highlight_max(subset=['Price (GBP)'], color='lightgreen') \
  .highlight_min(subset=['Price (GBP)'], color='lightcoral') \
  .set_caption("Book Data from books.toscrape.com")
# Out:
# <style type="text/css">
# ...
